# %%
import pandas as pd

df = pd.read_csv("/content/Match_Result_Data 2017-24.csv")
df.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  2017-08-11  19:45  Premier League  Matchweek 1  Fri  Away      L   3   4
# 1  2017-08-11  19:45  Premier League  Matchweek 1  Fri  Home      W   4   3
# 2  2017-08-12  15:00  Premier League  Matchweek 1  Sat  Home      D   0   0
# 3  2017-08-12  15:00  Premier League  Matchweek 1  Sat  Away      L   0   1
# 4  2017-08-12  15:00  Premier League  Matchweek 1  Sat  Away      L   0   1
#
#          opponent  ...  match report  notes  sh  sot  dist fk pk pkatt  \
# 0         Arsenal  ...  Match Report    NaN   6    3  10.5  0  0     0
# 1  Leicester City  ...  Match Report    NaN  27   10  19.7  0  0     0
# 2    Swansea City  ...  Match Report    NaN  29    2  17.8  1  0     0
# 3         Everton  ...  Match Report    NaN   9    1  22.6  0  0     0
# 4       West Brom  ...  Match Report    NaN   9    2  21.2  0  0     0
#
#    season            team
# 0    2022  Leicester City
# 1    2022         Arsenal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3099 entries, 0 to 3098
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3099 non-null   object
#  1   time          3099 non-null   object
#  2   comp          3099 non-null   object
#  3   round         3099 non-null   object
#  4   day           3099 non-null   object
#  5   venue         3099 non-null   object
#  6   result        3099 non-null   object
#  7   gf            3099 non-null   int64
#  8   ga            3099 non-null   int64
#  9   opponent      3099 non-null   object
#  10  xg            3099 non-null   float64
#  11  xga           3099 non-null   float64
#  12  poss          3099 non-null   int64
#  13  attendance    2403 non-null   float64
#  14  captain       3099 non-null   object
#  15  formation     3099 non-null   object
#  16  referee       3099 non-null   object
#  17  match report  3099 non-null   object
# ...

# %%
df1 = df.drop(['notes', 'attendance', 'formation'], axis=1)

# %%
df1.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'captain', 'referee', 'match report',
#        'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %% [markdown]
# Dataframe for the year 2020

# %%
df_2020 = df1[df1['date'].str.contains('2020')]
df_2020
# Out:
#             date   time            comp         round  day venue result  gf  \
# 1482  2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W   4
# 1483  2020-09-12  20:00  Premier League   Matchweek 1  Sat  Home      L   0
# 1484  2020-09-12  12:30  Premier League   Matchweek 1  Sat  Away      W   3
# 1485  2020-09-12  17:30  Premier League   Matchweek 1  Sat  Away      L   3
# 1486  2020-09-12  20:00  Premier League   Matchweek 1  Sat  Away      W   2
# ...          ...    ...             ...           ...  ...   ...    ...  ..
# 1787  2020-12-29  20:00  Premier League  Matchweek 16  Tue  Home      W   1
# 1788  2020-12-29  20:00  Premier League  Matchweek 16  Tue  Away      L   0
# 1789  2020-12-29  18:00  Premier League  Matchweek 16  Tue  Home      L   0
# 1790  2020-12-30  20:00  Premier League  Matchweek 16  Wed  Away      D   0
# 1791  2020-12-30  20:00  Premier League  Matchweek 16  Wed  Home      D   0
#
# ...

# %% [markdown]
# Dataframe for the year 2021

# %%
df_2021 = df1[df1['date'].str.contains('2021')]
df_2021
# Out:
#             date   time            comp         round  day venue result  gf  \
# 1792  2021-01-01  20:00  Premier League  Matchweek 17  Fri  Home      W   2
# 1793  2021-01-01  17:30  Premier League  Matchweek 17  Fri  Home      L   0
# 1794  2021-01-01  17:30  Premier League  Matchweek 17  Fri  Away      W   1
# 1795  2021-01-01  20:00  Premier League  Matchweek 17  Fri  Away      L   1
# 1796  2021-01-02  12:30  Premier League  Matchweek 17  Sat  Home      W   3
# ...          ...    ...             ...           ...  ...   ...    ...  ..
# 2584  2021-12-29  20:15  Premier League  Matchweek 20  Wed  Home      L   0
# 2585  2021-12-29  19:30  Premier League  Matchweek 20  Wed  Home      D   1
# 2586  2021-12-29  20:15  Premier League  Matchweek 20  Wed  Away      W   1
# 2587  2021-12-30  20:15  Premier League  Matchweek 20  Thu  Away      L   1
# 2588  2021-12-30  20:15  Premier League  Matchweek 20  Thu  Home      W   3
#
# ...

# %% [markdown]
# Dataframe for the year 2022

# %%
df_2022 = df1[df1['date'].str.contains('2022')]
df_2022
# Out:
#             date   time            comp         round  day venue result  gf  \
# 2589  2022-01-01  17:30  Premier League  Matchweek 21  Sat  Away      W   3
# 2590  2022-01-01  17:30  Premier League  Matchweek 21  Sat  Home      L   2
# 2591  2022-01-01  15:00  Premier League  Matchweek 21  Sat  Home      L   0
# 2592  2022-01-01  15:00  Premier League  Matchweek 21  Sat  Away      W   1
# 2593  2022-01-01  12:30  Premier League  Matchweek 21  Sat  Home      L   1
# ...          ...    ...             ...           ...  ...   ...    ...  ..
# 2866  2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L   0
# 2867  2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L   0
# 2868  2022-04-24  14:00  Premier League  Matchweek 34  Sun  Home      D   2
# 2869  2022-04-25  20:00  Premier League  Matchweek 34  Mon  Away      D   0
# 2870  2022-04-25  20:00  Premier League  Matchweek 34  Mon  Home      D   0
#
# ...

# %%
import matplotlib.pyplot as plt

# Group by team and count matches played, wins, and losses in 2020
team_stats_2020 = df_2020.groupby('team')['result'].agg(['count', lambda x: (x == 'W').sum(), lambda x: (x == 'L').sum()])
team_stats_2020.columns = ['Matches Played', 'Wins', 'Losses']

# Create a bar plot
team_stats_2020[['Wins', 'Losses']].plot(kind='bar', figsize=(10, 6))
plt.title('Team Matches Played, Wins, and Losses in 2020')
plt.xlabel('Team')
plt.ylabel('Number of Matches')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import matplotlib.pyplot as plt

# Group by team and count matches played, wins, and losses in 2020
team_stats_2021 = df_2021.groupby('team')['result'].agg(['count', lambda x: (x == 'W').sum(), lambda x: (x == 'L').sum()])
team_stats_2021.columns = ['Matches Played', 'Wins', 'Losses']

# Create a bar plot
team_stats_2021[['Wins', 'Losses']].plot(kind='bar', figsize=(10, 6))
plt.title('Team Matches Played, Wins, and Losses in 2021')
plt.xlabel('Team')
plt.ylabel('Number of Matches')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import matplotlib.pyplot as plt

# Group by team and count matches played, wins, and losses in 2020
team_stats_2022 = df_2022.groupby('team')['result'].agg(['count', lambda x: (x == 'W').sum(), lambda x: (x == 'L').sum()])
team_stats_2022.columns = ['Matches Played', 'Wins', 'Losses']

# Create a bar plot
team_stats_2022[['Wins', 'Losses']].plot(kind='bar', figsize=(10, 6))
plt.title('Team Matches Played, Wins, and Losses in 2020')
plt.xlabel('Team')
plt.ylabel('Number of Matches')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataframe is named 'df' and it contains 'team', 'result', 'venue' columns
# and the data for 2020 is filtered into df_2020

# Create a new column to identify home or away matches
df_2020['Home/Away'] = 'Away'
df_2020.loc[df_2020['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Pivot table to get the counts of wins for each team at home and away
team_wins_2020 = pd.pivot_table(df_2020[df_2020['result'] == 'W'], values='result', index='team', columns='Home/Away', aggfunc='count')
team_wins_2020 = team_wins_2020.fillna(0)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(team_wins_2020, annot=True, cmap='viridis', fmt='.0f')
plt.title('Team Home and Away Wins in 2020')
plt.xlabel('Home/Away')
plt.ylabel('Team')
plt.show()
# Out:
# <ipython-input-11-231021529f5d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['Home/Away'] = 'Away'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataframe is named 'df' and it contains 'team', 'result', 'venue' columns
# and the data for 2021 is filtered into df_2021

# Create a new column to identify home or away matches
df_2021['Home/Away'] = 'Away'
df_2021.loc[df_2021['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Pivot table to get the counts of wins for each team at home and away
team_wins_2021 = pd.pivot_table(df_2021[df_2021['result'] == 'W'], values='result', index='team', columns='Home/Away', aggfunc='count')
team_wins_2021 = team_wins_2021.fillna(0)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(team_wins_2021, annot=True, cmap='viridis', fmt='.0f')
plt.title('Team Home and Away Wins in 2021')
plt.xlabel('Home/Away')
plt.ylabel('Team')
plt.show()
# Out:
# <ipython-input-12-332d43a6044b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['Home/Away'] = 'Away'

# %%
# Assuming your dataframe is named 'df' and it contains 'team', 'result', 'venue' columns
# and the data for 2022 is filtered into df_2022

# Create a new column to identify home or away matches
df_2022['Home/Away'] = 'Away'
df_2022.loc[df_2022['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Pivot table to get the counts of wins for each team at home and away
team_wins_2022 = pd.pivot_table(df_2022[df_2022['result'] == 'W'], values='result', index='team', columns='Home/Away', aggfunc='count')
team_wins_2022 = team_wins_2022.fillna(0)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(team_wins_2022, annot=True, cmap='viridis', fmt='.0f')
plt.title('Team Home and Away Wins in 2022')
plt.xlabel('Home/Away')
plt.ylabel('Team')
plt.show()
# Out:
# <ipython-input-13-b8b818306f67>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['Home/Away'] = 'Away'

# %%
# Group by team and count matches played and losses
team_stats = df_2020.groupby('team')['result'].agg(['count', lambda x: (x == 'L').sum()])
team_stats.columns = ['Matches Played', 'Losses']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(team_stats['Matches Played'], team_stats['Losses'])
plt.title('Team Matches Played vs. Losses in 2020')
plt.xlabel('Matches Played')
plt.ylabel('Losses')
for team, row in team_stats.iterrows():
    plt.annotate(team, (row['Matches Played'], row['Losses']))
plt.show()

# %%
# Group by team and count matches played and wins
team_stats = df_2020.groupby('team')['result'].agg(['count', lambda x: (x == 'W').sum()])
team_stats.columns = ['Matches Played', 'Wins']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(team_stats['Matches Played'], team_stats['Wins'])
plt.title('Team Matches Played vs. Wins in 2020')
plt.xlabel('Matches Played')
plt.ylabel('Wins')
for team, row in team_stats.iterrows():
    plt.annotate(team, (row['Matches Played'], row['Wins']))
plt.show()

# %%
# Filter the dataframe for Arsenal matches in 2020
arsenal_2020 = df_2020[df_2020['team'] == 'Arsenal']

# Create a new column to identify home or away matches
arsenal_2020['Home/Away'] = 'Away'
arsenal_2020.loc[arsenal_2020['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(arsenal_2020[(arsenal_2020['result'] == 'W') & (arsenal_2020['Home/Away'] == 'Home')])
away_wins = len(arsenal_2020[(arsenal_2020['result'] == 'W') & (arsenal_2020['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Arsenal Home and Away Wins in 2020')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-16-7157a3e90571>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arsenal_2020['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Arsenal matches in 2021
arsenal_2021 = df_2021[df_2021['team'] == 'Arsenal']

# Create a new column to identify home or away matches
arsenal_2021['Home/Away'] = 'Away'
arsenal_2021.loc[arsenal_2021['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(arsenal_2021[(arsenal_2021['result'] == 'W') & (arsenal_2021['Home/Away'] == 'Home')])
away_wins = len(arsenal_2021[(arsenal_2021['result'] == 'W') & (arsenal_2021['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Arsenal Home and Away Wins in 2021')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-17-f10f389be5ec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arsenal_2021['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Arsenal matches in 2022
arsenal_2022 = df_2022[df_2022['team'] == 'Arsenal']

# Create a new column to identify home or away matches
arsenal_2022['Home/Away'] = 'Away'
arsenal_2022.loc[arsenal_2022['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(arsenal_2022[(arsenal_2022['result'] == 'W') & (arsenal_2022['Home/Away'] == 'Home')])
away_wins = len(arsenal_2022[(arsenal_2022['result'] == 'W') & (arsenal_2022['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Arsenal Home and Away Wins in 2022')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-18-5fc255ddc266>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arsenal_2022['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Aston Villa matches in 2020
aston_villa_2020 = df_2020[df_2020['team'] == 'Aston Villa']

# Create a new column to identify home or away matches
aston_villa_2020['Home/Away'] = 'Away'
aston_villa_2020.loc[aston_villa_2020['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(aston_villa_2020[(aston_villa_2020['result'] == 'W') & (aston_villa_2020['Home/Away'] == 'Home')])
away_wins = len(aston_villa_2020[(aston_villa_2020['result'] == 'W') & (aston_villa_2020['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Aston Villa Home and Away Wins in 2020')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-19-08bae0ef52a5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aston_villa_2020['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Aston Villa matches in 2021
aston_villa_2021 = df_2021[df_2021['team'] == 'Aston Villa']

# Create a new column to identify home or away matches
aston_villa_2021['Home/Away'] = 'Away'
aston_villa_2021.loc[aston_villa_2021['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(aston_villa_2021[(aston_villa_2021['result'] == 'W') & (aston_villa_2021['Home/Away'] == 'Home')])
away_wins = len(aston_villa_2021[(aston_villa_2021['result'] == 'W') & (aston_villa_2021['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Aston Villa Home and Away Wins in 2021')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-20-36768efcc0b5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aston_villa_2021['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Aston Villa matches in 2022
aston_villa_2022 = df_2022[df_2022['team'] == 'Aston Villa']

# Create a new column to identify home or away matches
aston_villa_2022['Home/Away'] = 'Away'
aston_villa_2022.loc[aston_villa_2022['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(aston_villa_2022[(aston_villa_2022['result'] == 'W') & (aston_villa_2022['Home/Away'] == 'Home')])
away_wins = len(aston_villa_2022[(aston_villa_2022['result'] == 'W') & (aston_villa_2022['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Aston Villa Home and Away Wins in 2022')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-21-0552dcc81e63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aston_villa_2022['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Burnley matches in 2020
burnley_2020 = df_2020[df_2020['team'] == 'Burnley']

# Create a new column to identify home or away matches
burnley_2020['Home/Away'] = 'Away'
burnley_2020.loc[burnley_2020['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(burnley_2020[(burnley_2020['result'] == 'W') & (burnley_2020['Home/Away'] == 'Home')])
away_wins = len(burnley_2020[(burnley_2020['result'] == 'W') & (burnley_2020['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Burnley Home and Away Wins in 2020')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-22-39465ad0db71>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   burnley_2020['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Burnley matches in 2021
burnley_2021 = df_2021[df_2021['team'] == 'Burnley']

# Create a new column to identify home or away matches
burnley_2021['Home/Away'] = 'Away'
burnley_2021.loc[burnley_2021['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(burnley_2021[(burnley_2021['result'] == 'W') & (burnley_2021['Home/Away'] == 'Home')])
away_wins = len(burnley_2021[(burnley_2021['result'] == 'W') & (burnley_2021['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Burnley Home and Away Wins in 2021')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-23-024e7192f2fb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   burnley_2021['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Burnley matches in 2022
burnley_2022 = df_2022[df_2022['team'] == 'Burnley']

# Create a new column to identify home or away matches
burnley_2022['Home/Away'] = 'Away'
burnley_2022.loc[burnley_2022['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(burnley_2022[(burnley_2022['result'] == 'W') & (burnley_2022['Home/Away'] == 'Home')])
away_wins = len(burnley_2022[(burnley_2022['result'] == 'W') & (burnley_2022['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Burnley Home and Away Wins in 2022')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-24-8fdd56272216>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   burnley_2022['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Chelsea matches in 2020
chelsea_2020 = df_2020[df_2020['team'] == 'Chelsea']

# Create a new column to identify home or away matches
chelsea_2020['Home/Away'] = 'Away'
chelsea_2020.loc[chelsea_2020['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(chelsea_2020[(chelsea_2020['result'] == 'W') & (chelsea_2020['Home/Away'] == 'Home')])
away_wins = len(chelsea_2020[(chelsea_2020['result'] == 'W') & (chelsea_2020['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Chelsea Home and Away Wins in 2020')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-25-d6ea0adffb20>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chelsea_2020['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Chelsea matches in 2021
chelsea_2021 = df_2021[df_2021['team'] == 'Chelsea']

# Create a new column to identify home or away matches
chelsea_2021['Home/Away'] = 'Away'
chelsea_2021.loc[chelsea_2021['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(chelsea_2021[(chelsea_2021['result'] == 'W') & (chelsea_2021['Home/Away'] == 'Home')])
away_wins = len(chelsea_2021[(chelsea_2021['result'] == 'W') & (chelsea_2021['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Chelsea Home and Away Wins in 2021')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-26-1c4b9f9cac02>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chelsea_2021['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Chelsea matches in 2022
chelsea_2022 = df_2022[df_2022['team'] == 'Chelsea']

# Create a new column to identify home or away matches
chelsea_2022['Home/Away'] = 'Away'
chelsea_2022.loc[chelsea_2022['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(chelsea_2022[(chelsea_2022['result'] == 'W') & (chelsea_2022['Home/Away'] == 'Home')])
away_wins = len(chelsea_2022[(chelsea_2022['result'] == 'W') & (chelsea_2022['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Chelsea Home and Away Wins in 2022')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-27-f1b706b986b0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chelsea_2022['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Manchester United matches in 2020
manchester_united_2020 = df_2020[df_2020['team'] == 'Manchester United']

# Create a new column to identify home or away matches
manchester_united_2020['Home/Away'] = 'Away'
manchester_united_2020.loc[manchester_united_2020['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(manchester_united_2020[(manchester_united_2020['result'] == 'W') & (manchester_united_2020['Home/Away'] == 'Home')])
away_wins = len(manchester_united_2020[(manchester_united_2020['result'] == 'W') & (manchester_united_2020['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Manchester United Home and Away Wins in 2020')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-28-0321f2627e6e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manchester_united_2020['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Manchester United matches in 2021
manchester_united_2021 = df_2021[df_2021['team'] == 'Manchester United']

# Create a new column to identify home or away matches
manchester_united_2021['Home/Away'] = 'Away'
manchester_united_2021.loc[manchester_united_2021['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(manchester_united_2021[(manchester_united_2021['result'] == 'W') & (manchester_united_2021['Home/Away'] == 'Home')])
away_wins = len(manchester_united_2021[(manchester_united_2021['result'] == 'W') & (manchester_united_2021['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Manchester United Home and Away Wins in 2021')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-29-ea015f297572>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manchester_united_2021['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Manchester United matches in 2022
manchester_united_2022 = df_2022[df_2022['team'] == 'Manchester United']

# Create a new column to identify home or away matches
manchester_united_2022['Home/Away'] = 'Away'
manchester_united_2022.loc[manchester_united_2022['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(manchester_united_2022[(manchester_united_2022['result'] == 'W') & (manchester_united_2022['Home/Away'] == 'Home')])
away_wins = len(manchester_united_2022[(manchester_united_2022['result'] == 'W') & (manchester_united_2022['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Manchester United Home and Away Wins in 2022')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-30-cc6bad645534>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manchester_united_2022['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Manchester City matches in 2020
manchester_city_2020 = df_2020[df_2020['team'] == 'Manchester City']

# Create a new column to identify home or away matches
manchester_city_2020['Home/Away'] = 'Away'
manchester_city_2020.loc[manchester_city_2020['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(manchester_city_2020[(manchester_city_2020['result'] == 'W') & (manchester_city_2020['Home/Away'] == 'Home')])
away_wins = len(manchester_city_2020[(manchester_city_2020['result'] == 'W') & (manchester_city_2020['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Manchester City Home and Away Wins in 2020')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-31-fcddab545d72>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manchester_city_2020['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Manchester United matches in 2021
manchester_united_2021 = df_2021[df_2021['team'] == 'Manchester United']

# Create a new column to identify home or away matches
manchester_united_2021['Home/Away'] = 'Away'
manchester_united_2021.loc[manchester_united_2021['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(manchester_united_2021[(manchester_united_2021['result'] == 'W') & (manchester_united_2021['Home/Away'] == 'Home')])
away_wins = len(manchester_united_2021[(manchester_united_2021['result'] == 'W') & (manchester_united_2021['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Manchester United Home and Away Wins in 2021')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-32-ea015f297572>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manchester_united_2021['Home/Away'] = 'Away'

# %%
# Filter the dataframe for Manchester United matches in 2022
manchester_united_2022 = df_2022[df_2022['team'] == 'Manchester United']

# Create a new column to identify home or away matches
manchester_united_2022['Home/Away'] = 'Away'
manchester_united_2022.loc[manchester_united_2022['venue'].str.contains('Home'), 'Home/Away'] = 'Home'

# Calculate the number of home and away wins
home_wins = len(manchester_united_2022[(manchester_united_2022['result'] == 'W') & (manchester_united_2022['Home/Away'] == 'Home')])
away_wins = len(manchester_united_2022[(manchester_united_2022['result'] == 'W') & (manchester_united_2022['Home/Away'] == 'Away')])

# Create the pie chart
labels = ['Home Wins', 'Away Wins']
sizes = [home_wins, away_wins]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 1st slice (Home Wins)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Manchester United Home and Away Wins in 2022')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# <ipython-input-33-cc6bad645534>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manchester_united_2022['Home/Away'] = 'Away'
